# %% [markdown]
# # Closed Deals - Silver Transformation

# %% [markdown]
# ## Setup

# %%
from pyspark.sql.functions import col, trim

environment = "dev"

catalog = f"ecommerce_{environment}"
source_table = f"{catalog}.bronze.olist_closed_deals"
target_table = f"{catalog}.silver.olist_closed_deals"

# %% [markdown]
# ## Read Bronze data

# %%
bronze_df = spark.table(source_table)

# %% [markdown]
# ## Review the data

# %%
bronze_df.printSchema()
# Out:
# root
#  |-- mql_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- sdr_id: string (nullable = true)
#  |-- sr_id: string (nullable = true)
#  |-- won_date: timestamp (nullable = true)
#  |-- business_segment: string (nullable = true)
#  |-- lead_type: string (nullable = true)
#  |-- lead_behaviour_profile: string (nullable = true)
#  |-- has_company: boolean (nullable = true)
#  |-- has_gtin: boolean (nullable = true)
#  |-- average_stock: string (nullable = true)
#  |-- business_type: string (nullable = true)
#  |-- declared_product_catalog_size: decimal(10,1) (nullable = true)
#  |-- declared_monthly_revenue: decimal(18,2) (nullable = true)
#  |-- _rescued_data: string (nullable = true)
#  |-- source_file_path: string (nullable = true)
#  |-- source_file_modification_time: timestamp (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- ingestion_run_id: string (nullable = true)
#  |-- source_system: string (nullable = true)
#  |-- source_dataset: string (nullable = true)

# %%
display(bronze_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mql_id</th><th>seller_id</th><th>sdr_id</th><th>sr_id</th><th>won_date</th><th>business_segment</th><th>lead_type</th><th>lead_behaviour_profile</th><th>has_company</th><th>has_gtin</th><th>average_stock</th><th>business_type</th><th>declared_product_catalog_size</th><th>declared_monthly_revenue</th><th>_rescued_data</th><th>source_file_path</th><th>source_file_modification_time</th><th>ingestion_timestamp</th><th>ingestion_run_id</th><th>source_system</th><th>source_dataset</th></tr></thead><tbody><tr><td>5420aad7fec3549a85876ba1c529bd84</td><td>2c43fb513632d29b3b58df74816f1b06</td><td>a8387c01a09e99ce014107505b92388c</td><td>4ef15afb4b2723d8f3d81e51ec7afefe</td><td>2018-02-26T19:58:54.000Z</td><td>pet</td><td>online_medium</td><td>cat</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>a555fb36b9368110ede0f043dfc3b9a0</td><td>bbb7d7893a450660432ea6652310ebb7</td><td>09285259593c61296eef10c734121d5b</td><td>d3d1e91a157ea7f90548eef82f1955e3</td><td>2018-05-08T20:17:59.000Z</td><td>car_accessories</td><td>industry</td><td>eagle</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>327174d3648a2d047e8940d7d15204ca</td><td>612170e34b97004b3ba37eae81836b4c</td><td>b90f87164b5f8c2cfa5c8572834dbe3f</td><td>6565aa9ce3178a5caf6171827af3a9ba</td><td>2018-06-05T17:27:23.000Z</td><td>home_appliances</td><td>online_big</td><td>cat</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>f5fee8f7da74f4887f5bcae2bafb6dd6</td><td>21e1781e36faf92725dde4730a88ca0f</td><td>56bf83c4bb35763a51c2baab501b4c67</td><td>d3d1e91a157ea7f90548eef82f1955e3</td><td>2018-01-17T13:51:03.000Z</td><td>food_drink</td><td>online_small</td><td>null</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>ffe640179b554e295c167a2f6be528e0</td><td>ed8cb7b190ceb6067227478e48cf8dde</td><td>4b339f9567d060bcea4f5136b9f5949e</td><td>d3d1e91a157ea7f90548eef82f1955e3</td><td>2018-07-03T20:17:45.000Z</td><td>home_appliances</td><td>industry</td><td>wolf</td><td>null</td><td>null</td><td>null</td><td>manufacturer</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>b94fba7670eeb44dce2a0d8eb790e9f5</td><td>1c742ac33582852aaf3bcfbf5893abcf</td><td>fdb16d3cbbeb5798f2f66c4096be026d</td><td>495d4e95a8cf8bbf8b432b612a2aa328</td><td>2018-02-07T18:04:05.000Z</td><td>health_beauty</td><td>online_medium</td><td>null</td><td>null</td><td>null< ...

# %%
print("Number of rows:", bronze_df.count())
print("Number of columns:", len(bronze_df.columns))
# Out:
# Number of rows: 842
# Number of columns: 21

# %%
rescued_row_count = (
    bronze_df
    .filter(col("_rescued_data").isNotNull())
    .filter(trim(col("_rescued_data")) != "")
    .count()
)

print("Number of rescued rows:", rescued_row_count)
# Out:
# Number of rescued rows: 0

# %%
for column, dtype in bronze_df.dtypes[:14]:
    print(column)
    print("Null count:", bronze_df.filter(col(column).isNull()).count())
    print("Distinct count:", bronze_df.filter(col(column).isNotNull()).select(column).distinct().count())

    if dtype == "string":
        print("Extra whitespace row count:",
            (
                bronze_df.withColumn(f"{column}_trimmed", trim(col(column)))
                .filter(col(column) != col(f"{column}_trimmed"))
                .count()
            )
        )
    print("-"*20)
# Out:
# mql_id
# Null count: 0
# Distinct count: 842
# Extra whitespace row count: 0
# --------------------
# seller_id
# Null count: 0
# Distinct count: 842
# Extra whitespace row count: 0
# --------------------
# sdr_id
# Null count: 0
# Distinct count: 32
# Extra whitespace row count: 0
# --------------------
# sr_id
# Null count: 0
# Distinct count: 22
# Extra whitespace row count: 0
# --------------------
# won_date
# Null count: 0
# Distinct count: 824
# --------------------
# business_segment
# Null count: 1
# Distinct count: 33
# Extra whitespace row count: 0
# --------------------
# lead_type
# Null count: 6
# Distinct count: 8
# Extra whitespace row count: 0
# --------------------
# lead_behaviour_profile
# Null count: 177
# Distinct count: 9
# Extra whitespace row count: 0
# --------------------
# has_company
# Null count: 779
# Distinct count: 2
# --------------------
# has_gtin
# Null count: 778
# Distinct count: 2
# --------------------
# average_stock
# Null count: 776
# Distinct count: 6
# Extra whitespace row count: 0
# --------------------
# business_type
# Null count: 10
# Distinct count: 3
# Extra whitespace row count: 0
# --------------------
# declared_product_catalog_size
# Null count: 773
# Distinct count: 33
# --------------------
# declared_monthly_revenue
# Null count: 0
# Distinct count: 27
# --------------------

# %% [markdown]
# - mql_id is complete and unique, so it is the key.
# - seller_id is also unique here, but it is a foreign key.

# %%
print(
    bronze_df
    .filter(
        col("declared_product_catalog_size").isNotNull()
        & (
            col("declared_product_catalog_size")
            != col("declared_product_catalog_size").cast("int")
        )
    )
    .count()
)
# Out:
# 0

# %% [markdown]
# the original decimal values are not different from the converted integer values

# %% [markdown]
# ## Transform to Silver

# %%
silver_df = (
    bronze_df
    .withColumnRenamed(
        "mql_id",
        "marketing_qualified_lead_id"
    )
    .withColumnRenamed(
        "sdr_id",
        "sales_development_representative_id"
    )
    .withColumnRenamed(
        "sr_id",
        "sales_representative_id"
    )
    .withColumnRenamed(
        "won_date",
        "deal_won_date"
    )
    .withColumnRenamed(
        "has_gtin",
        "has_global_trade_item_number"
    )
)

# %%
silver_df = silver_df.withColumn(
    "declared_product_catalog_size",
    col("declared_product_catalog_size").cast("int")
)

# %% [markdown]
# ## Write to Silver

# %%
(
    silver_df.write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(target_table)
)

# %% [markdown]
# ## Review the result

# %%
silver_table_df = spark.table(target_table)

silver_table_df.printSchema()
# Out:
# root
#  |-- marketing_qualified_lead_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- sales_development_representative_id: string (nullable = true)
#  |-- sales_representative_id: string (nullable = true)
#  |-- deal_won_date: timestamp (nullable = true)
#  |-- business_segment: string (nullable = true)
#  |-- lead_type: string (nullable = true)
#  |-- lead_behaviour_profile: string (nullable = true)
#  |-- has_company: boolean (nullable = true)
#  |-- has_global_trade_item_number: boolean (nullable = true)
#  |-- average_stock: string (nullable = true)
#  |-- business_type: string (nullable = true)
#  |-- declared_product_catalog_size: integer (nullable = true)
#  |-- declared_monthly_revenue: decimal(18,2) (nullable = true)
#  |-- _rescued_data: string (nullable = true)
#  |-- source_file_path: string (nullable = true)
#  |-- source_file_modification_time: timestamp (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- ingestion_run_id: string (nullable = true)
#  |-- source_system: string (nullable = true)
#  |-- source_dataset: string (nullable = true)

# %%
display(silver_table_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>marketing_qualified_lead_id</th><th>seller_id</th><th>sales_development_representative_id</th><th>sales_representative_id</th><th>deal_won_date</th><th>business_segment</th><th>lead_type</th><th>lead_behaviour_profile</th><th>has_company</th><th>has_global_trade_item_number</th><th>average_stock</th><th>business_type</th><th>declared_product_catalog_size</th><th>declared_monthly_revenue</th><th>_rescued_data</th><th>source_file_path</th><th>source_file_modification_time</th><th>ingestion_timestamp</th><th>ingestion_run_id</th><th>source_system</th><th>source_dataset</th></tr></thead><tbody><tr><td>5420aad7fec3549a85876ba1c529bd84</td><td>2c43fb513632d29b3b58df74816f1b06</td><td>a8387c01a09e99ce014107505b92388c</td><td>4ef15afb4b2723d8f3d81e51ec7afefe</td><td>2018-02-26T19:58:54.000Z</td><td>pet</td><td>online_medium</td><td>cat</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>a555fb36b9368110ede0f043dfc3b9a0</td><td>bbb7d7893a450660432ea6652310ebb7</td><td>09285259593c61296eef10c734121d5b</td><td>d3d1e91a157ea7f90548eef82f1955e3</td><td>2018-05-08T20:17:59.000Z</td><td>car_accessories</td><td>industry</td><td>eagle</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>327174d3648a2d047e8940d7d15204ca</td><td>612170e34b97004b3ba37eae81836b4c</td><td>b90f87164b5f8c2cfa5c8572834dbe3f</td><td>6565aa9ce3178a5caf6171827af3a9ba</td><td>2018-06-05T17:27:23.000Z</td><td>home_appliances</td><td>online_big</td><td>cat</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>f5fee8f7da74f4887f5bcae2bafb6dd6</td><td>21e1781e36faf92725dde4730a88ca0f</td><td>56bf83c4bb35763a51c2baab501b4c67</td><td>d3d1e91a157ea7f90548eef82f1955e3</td><td>2018-01-17T13:51:03.000Z</td><td>food_drink</td><td>online_small</td><td>null</td><td>null</td><td>null</td><td>null</td><td>reseller</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>ffe640179b554e295c167a2f6be528e0</td><td>ed8cb7b190ceb6067227478e48cf8dde</td><td>4b339f9567d060bcea4f5136b9f5949e</td><td>d3d1e91a157ea7f90548eef82f1955e3</td><td>2018-07-03T20:17:45.000Z</td><td>home_appliances</td><td>industry</td><td>wolf</td><td>null</td><td>null</td><td>null</td><td>manufacturer</td><td>null</td><td>0.00</td><td>null</td><td>/Volumes/ecommerce_dev/landing/raw_files/olist_marketing/closed_deals/olist_closed_deals_dataset.csv</td><td>2026-08-02T21:45:38.000Z</td><td>2026-08-03T01:43:34.590Z</td><td>cc7d51c8-a726-4bd8-8263-bfa64c6a89d6</td><td>olist_marketing</td><td>closed_deals</td></tr><tr><td>b94fba7670eeb44dce2a0d8eb790e9f5</td><td>1c742ac33582852aaf3bcfbf5893abcf</td><td>fdb16d3cbbeb5798f2f66c4096be026d</td><td>495d4e95a8cf8bbf8b432b612a2aa328</td><td>2018-02-07T18:0 ...

# %%
print("Bronze row count:", bronze_df.count())
print("Silver row count:", silver_table_df.count())
# Out:
# Bronze row count: 842
# Silver row count: 842
